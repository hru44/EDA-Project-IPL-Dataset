# %%
#Importing all the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the data
data = pd.read_csv("C:\\Users\\rutu\\Desktop\\python folder\\deliveries.csv")
data.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1 = pd.read_csv("C:\\Users\\rutu\\Desktop\\python folder\\matches.csv")
data1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (179078, 21)

# %%
data1.shape
# Out:
# (756, 18)

# %%
data.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
data1.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
data.isnull().sum().sum()
# Out:
# 513118

# %%
data1.isnull().sum().sum()
# Out:
# 656

# %%
#How many IPL seasoned are we using to analyse ?
data1['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
len(data1['season'].unique())
# Out:
# 12

# %%
# Total number of innings of the matches played?
data['inning'].value_counts().sum()
# Out:
# 179078

# %%
# Which IPL team won by maximum runs?
data1.loc[data1['win_by_runs'].max()]['winner']
# Out:
# 'Deccan Chargers'

# %%
# Which IPL team won by minimum runs?
data1.loc[data1['win_by_runs'].min()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %%
# Which IPL team won by consuming minimum wickets?
data1.loc[data1['win_by_wickets'].min()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %% [markdown]
# # Visualization

# %%
# Which season consisted of the highest number of matches ever played?
sns.countplot(x = 'season', data = data1)
plt.title("Matches Played in each season", fontsize = 11)
# Out:
# Text(0.5, 1.0, 'Matches Played in each season')

# %% [markdown]
# Inferance of above graph
#
# In 2013 highest number of matches ever played

# %%
# Which is the most successful IPL team with all the data at hand?
succ = data1.winner.value_counts()

# %%
succ
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
sns.barplot(y = succ.index, x = succ, orient = 'h')
plt.title('Most successful IPL Team', fontsize = 11)
# Out:
# Text(0.5, 1.0, 'Most successful IPL Team')

# %% [markdown]
# Inferance of above graph
#
# Mumbai Indians is the most successful team in graph

# %%
# Top players of winning matches
top_players = data1.player_of_match.value_counts().head(10)
top_players
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
sns.barplot(y= top_players.index, x = top_players)
plt.title('Top players of winning matches')
# Out:
# Text(0.5, 1.0, 'Top players of winning matches')

# %% [markdown]
# Inferance of above graph
#
# In the charts, Top 10 players winning the match and the highest winning player is CH Gayle.

# %%
# Matches according to venue
Matches = data1.venue.value_counts().head(10)
Matches
# Out:
# Eden Gardens                                  77
# M Chinnaswamy Stadium                         73
# Wankhede Stadium                              73
# Feroz Shah Kotla                              67
# Rajiv Gandhi International Stadium, Uppal     56
# MA Chidambaram Stadium, Chepauk               49
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Maharashtra Cricket Association Stadium       21
# Subrata Roy Sahara Stadium                    17
# Name: venue, dtype: int64

# %%
sns.barplot(y = Matches.index, x = Matches)
plt.title('Matches according to venue', fontsize = 11)
# Out:
# Text(0.5, 1.0, 'Matches according to venue')

# %% [markdown]
# Inferance of above graph
#
# The most matches are held in Eden Gardens

# %%
# The number of matches played by each team
a = data1.team1.value_counts()
b = data1.team2.value_counts()
match_played = a+b
match_played
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
sns.barplot(y= match_played.index, x= match_played, orient = 'h')
plt.title('The number of matches played by each team', fontsize = 11)
# Out:
# Text(0.5, 1.0, 'The number of matches played by each team')

# %% [markdown]
# Inferance of above graph
#
# Mumbai Indians played 187 matches more than other teams.

# %%
# The winners in each Season
# IPL Finals venues and winners along with the number of wins.
# The number of seasons won by each team.
# The toss winner, toss decision, winner in final matches.
# The man of the match for each winning team.
# Decision in every toss either fielding or batting.

# %%
# The winners in each Season
winners = data1.groupby(['season','winner'])['id'].count().reset_index()
winners
# Out:
#     season                       winner  id
# 0     2008          Chennai Super Kings   9
# 1     2008              Deccan Chargers   2
# 2     2008             Delhi Daredevils   7
# 3     2008              Kings XI Punjab  10
# 4     2008        Kolkata Knight Riders   6
# ..     ...                          ...  ..
# 95    2019        Kolkata Knight Riders   6
# 96    2019               Mumbai Indians  11
# 97    2019             Rajasthan Royals   5
# 98    2019  Royal Challengers Bangalore   5
# 99    2019          Sunrisers Hyderabad   6
#
# [100 rows x 3 columns]

# %%
winners.pivot_table(values = 'winner', index = 'season', columns = 'winner').fillna(0)
# Out:
# winner  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# season
# 2008                    9.0              2.0             0.0
# 2009                    8.0              9.0             0.0
# 2010                    9.0              8.0             0.0
# 2011                   11.0              6.0             0.0
# 2012                   10.0              4.0             0.0
# 2013                   12.0              0.0             0.0
# 2014                   10.0              0.0             0.0
# 2015                   10.0              0.0             0.0
# 2016                    0.0              0.0             0.0
# 2017                    0.0              0.0             0.0
# 2018                   11.0              0.0             0.0
# 2019                   10.0              0.0            10.0
#
# winner  Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# season
# 2008                 7.0            0.0             10.0
# ...

# %%
a = winners.pivot_table(values = 'winner', index = 'season', columns = 'winner').fillna(0)
sns.heatmap(a)
# Out:
# <Axes: xlabel='winner', ylabel='season'>

# %%
# IPL Finals venues and winners along with the number of wins.

matches_won_at_venue = data1.groupby(['venue','winner'])['id'].count().reset_index().head(50)
matches_won_matrix = matches_won_at_venue.pivot('venue','winner','id').fillna(0)

plt.figure(figsize = (12,8))
matches_won_matrix.plot(kind = 'bar', stacked = True, colormap = 'tab20')
plt.xlabel('venue')
plt.ylabel('Number of matches won')
plt.title('Number of matches won by each team at each venue')

plt.legend(title = 'winner', bbox_to_anchor = (1,1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 8
#       6 plt.figure(figsize = (12,8))
#       7 matches_won_matrix.plot(kind = 'bar', stacked = True, colormap = 'tab20')
# ----> 8 plt.xlabel('venue')
#       9 plt.ylabel('Number of matches won')
#      10 plt.title('Number of matches won by each team at each venue')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Inferance of above graph
#
# The number of match won by sunrise hyderabad in eden gardens

# %%
# Decision in every toss either fielding or batting

toss_winners = data1.toss_decision.value_counts()
toss_winners
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(x ='season',hue = 'toss_decision', data=data1)
plt.show()

# %% [markdown]
# Inferance of above graph
#
# In Every Toss every team always choose Fielding more than Batting.

# %%
data1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# The man of the match for each winning team
man_of_the_match = data1.groupby(['winner','player_of_match'])['id'].count().reset_index()
a = man_of_the_match.pivot('winner','player_of_match','id').fillna(0)
plt.figure(figsize = (12,6))
sns.heatmap(a)
plt.title('The man of the match for each winning team')
plt.xlabel=('Player of the match')
plt.ylabel=('Winning team')

# %% [markdown]
# Inferance of above graph
#
# In this graph, AB De Villiers are man of the match.

# %%
# The toss winner, toss decision, winner in final matches.

toss_winners = data1.groupby(['toss_winner','toss_decision'])['winner'].count().reset_index()
a = toss_winners.pivot('toss_winner','toss_decision','winner').fillna(0)

plt.figure(figsize =(12,6))
a.plot(kind = 'bar', colormap='tab20')
plt.xlabel=('Toss winner')
plt.ylabel=('Toss decision')
plt.title('The Toss winner,toss decision,winner in final matches.')
# Out:
# Text(0.5, 1.0, 'The Toss winner,toss decision,winner in final matches.')

# %% [markdown]
# Inferance of above graph
#
# Toss Winner,Toss Decision and Winner in final matches are kolkata knights riders.

# %% [markdown]
# What is the probability of winning a match if the toss was won?
#
# The total runs by fours hit and the total number of fours hit by each team
#
# The fours hit by players
#
# The number of fours hit in each season
#
# The total runs by the sixes hit and the number of sixes hit by each team
#
# The number of sixes hit in each season
#
# The top 10 leading run scores in IPL

# %%
# The total runs by fours hit and the total number of fours hit by each team

fours = data[data['batsman_runs']==4]
a = fours.groupby('batting_team')['batsman_runs'].agg([('Total runs by four','sum'),('Fours','count')])
a
# Out:
#                              Total runs by four  Fours
# batting_team
# Chennai Super Kings                        8772   2193
# Deccan Chargers                            3828    957
# Delhi Capitals                              968    242
# Delhi Daredevils                           8632   2158
# Gujarat Lions                              1840    460
# Kings XI Punjab                            9832   2458
# Kochi Tuskers Kerala                        680    170
# Kolkata Knight Riders                      9736   2434
# Mumbai Indians                            10352   2588
# Pune Warriors                              2100    525
# Rajasthan Royals                           8140   2035
# Rising Pune Supergiant                      788    197
# Rising Pune Supergiants                     684    171
# Royal Challengers Bangalore                9440   2360
# Sunrisers Hyderabad                        5776   1444

# %%
plt.figure(figsize = (12,5))
a.plot(kind = 'bar', colormap = 'tab20')
plt.xlabel=('Batting_team')
plt.ylabel=('Fours')
plt.title('The total runs by fours hit by each team.')
# Out:
# Text(0.5, 1.0, 'The total runs by fours hit by each team.')

# %% [markdown]
# Inferance of above graph
#
# The Total number of fours hit by Mumbai Indians

# %%
#The fours hit by players
batsman_four = data[data['batsman_runs']==4]
a = batsman_four.groupby('batsman')['batsman_runs'].agg([('four','count')]).reset_index()
a
# Out:
#             batsman  four
# 0    A Ashish Reddy    16
# 1          A Chopra     7
# 2       A Choudhary     1
# 3        A Flintoff     5
# 4           A Hales    13
# ..              ...   ...
# 405       YK Pathan   264
# 406     YV Takawale    26
# 407   Yashpal Singh     5
# 408    Yuvraj Singh   218
# 409          Z Khan    11
#
# [410 rows x 2 columns]

# %%
b = a.iloc[:10,:].plot('batsman','four',kind = 'bar', color = 'red')
plt.xlabel = ('Player name')
plt.ylabel = ('Number of fours')
plt.title('The fours hit by players')
plt.show()

# %% [markdown]
# Inferance of above graph
#
# In chart, we show the most fours hit by A Mishra

# %%
#The total runs by the sixes hit and the number of sixes hit by each team.

six_data = data[data['batsman_runs']==6]
a = six_data.groupby('batting_team')['batsman_runs'].agg([('Total runs by six','sum'),('six','count')])
a
# Out:
#                              Total runs by six   six
# batting_team
# Chennai Super Kings                       5838   973
# Deccan Chargers                           2400   400
# Delhi Capitals                             522    87
# Delhi Daredevils                          4806   801
# Gujarat Lions                              930   155
# Kings XI Punjab                           5856   976
# Kochi Tuskers Kerala                       318    53
# Kolkata Knight Riders                     5580   930
# Mumbai Indians                            6576  1096
# Pune Warriors                             1176   196
# Rajasthan Royals                          4086   681
# Rising Pune Supergiant                     534    89
# Rising Pune Supergiants                    408    68
# Royal Challengers Bangalore               6792  1132
# Sunrisers Hyderabad                       3198   533

# %%
plt.figure(figsize=(12,8))
a.plot(kind='bar', colormap='tab20')
plt.xlabel=('batting team')
plt.ylabel=('Number of six')
plt.title('The total runs by six hit by each team')
# Out:
# Text(0.5, 1.0, 'The total runs by six hit by each team')

# %% [markdown]
# Inferance of above graph
#
# In this graph we show that most runs hitted by six royal challengers bangalore

# %%
# The number of sixes hit in each season

sixes = data[data['batsman_runs']==6]
a = sixes.groupby('batsman')['batsman_runs'].agg([('six','count')]).reset_index()
a
# Out:
#              batsman  six
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3            A Hales    6
# 4           A Mishra    5
# ..               ...  ...
# 331  Y Venugopal Rao   37
# 332        YK Pathan  161
# 333      YV Takawale    3
# 334     Yuvraj Singh  149
# 335           Z Khan    2
#
# [336 rows x 2 columns]

# %%
b = a.iloc[:10,:].plot('batsman','six', kind = 'bar', color = 'yellow')
plt.xlabel = ('Player name')
plt.ylabel = ('Number of six')
plt.title('The six hit by players ')
plt.show()

# %% [markdown]
# Inferance of above graph
#
# The most six hit by A Symonds

# %% [markdown]
# ## Conclusion
# In this comprehensive data analysis project centered around the Indian Premier League(IPL), I harnessed the power of Python libraries such as Pandas, numpy, and matplotlib to delve into a wealth  of data spanning IPL matches from 2008 to 2017. With the overarching aim of shedding light on various dimension of IPL games, I meticulously applied data cleaning techniques to ensure the integrity and relevance of the dataset. My analysis encompassed both player-level information, including batting and bowling statistics and match-level deatils such as venues, winners and scores.
#
# Concluding this analysis, I diligently tackled several pivotal questions that have piqued the curisosity of IPL enthusiasts and  data professionals alike
